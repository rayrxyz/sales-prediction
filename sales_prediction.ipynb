# %% [markdown]
# <a href="https://colab.research.google.com/github/vincebarokie/sales-prediction/blob/main/sales_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Project : Sales Prediction
#
# This project will be a sales prediction for food items sold at various stores. The goal of this is to help the retailer understand the properties of products and outlets that play crucial roles in increasing sales.

# %% [markdown]
# ## Data Loading and Cleanup
#
# * Load the CSV file to a DataFrame
# * Explore and do necessary data preparation and cleanup

# %% [markdown]
# ### Mounting and Loading
#
# * Mount the drive
# * Import libraries
# * Load CSV as DataFrame

# %%
# install required packages
# %pip install datawig
# Out:
# Requirement already satisfied: datawig in /usr/local/lib/python3.7/dist-packages (0.2.0)
# Requirement already satisfied: typing==3.6.6 in /usr/local/lib/python3.7/dist-packages (from datawig) (3.6.6)
# Requirement already satisfied: scikit-learn[alldeps]==0.22.1 in /usr/local/lib/python3.7/dist-packages (from datawig) (0.22.1)
# Requirement already satisfied: mxnet==1.4.0 in /usr/local/lib/python3.7/dist-packages (from datawig) (1.4.0)
# Requirement already satisfied: pandas==0.25.3 in /usr/local/lib/python3.7/dist-packages (from datawig) (0.25.3)
# Requirement already satisfied: numpy<1.15.0,>=1.8.2 in /usr/local/lib/python3.7/dist-packages (from mxnet==1.4.0->datawig) (1.14.6)
# Requirement already satisfied: requests>=2.20.0 in /usr/local/lib/python3.7/dist-packages (from mxnet==1.4.0->datawig) (2.23.0)
# Requirement already satisfied: graphviz<0.9.0,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from mxnet==1.4.0->datawig) (0.8.4)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas==0.25.3->datawig) (2018.9)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.7/dist-packages (from pandas==0.25.3->datawig) (2.8.2)
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn[alldeps]==0.22.1->datawig) (1.4.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn[alldeps]==0.22.1->datawig) (1.1.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.6.1->pandas==0.25.3->datawig) (1.15.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.20.0->mxnet==1.4.0->datawig) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.20.0->mxnet==1.4.0->datawig) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.20.0->mxnet==1.4.0->datawig) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.20.0->mxnet==1.4.0->datawig) (2.10)

# %%
# mount drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# import libraries
import pandas as pd
import numpy as np
import datawig

# %%
# load sales_predictions.csv file to df
filename = '/content/drive/MyDrive/CodingDojo_DS/Project/sales_predictions.csv'
df = pd.read_csv(filename)
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998         NaN               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1          3735.1380
# 1  Supermarket Type2           443.4228
# 2  Supermarket Type1          2097.2700
# 3      Grocery Store           732.3800
# 4  Supermarket Type1           994.7052

# %% [markdown]
# ### DataFrame Shape
#
# Get how many rows and columns are in the DataFrame

# %%
# How many rows and columns? 
df.shape
# Out:
# (8523, 12)

# %% [markdown]
# ### DataFrame Info
#
# * Get the columns and each dtypes
# * Find how many columns have missing values

# %%
# dtypes of each variable
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
# Item_Identifier              8523 non-null object
# Item_Weight                  7060 non-null float64
# Item_Fat_Content             8523 non-null object
# Item_Visibility              8523 non-null float64
# Item_Type                    8523 non-null object
# Item_MRP                     8523 non-null float64
# Outlet_Identifier            8523 non-null object
# Outlet_Establishment_Year    8523 non-null int64
# Outlet_Size                  6113 non-null object
# Outlet_Location_Type         8523 non-null object
# Outlet_Type                  8523 non-null object
# Item_Outlet_Sales            8523 non-null float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %% [markdown]
# ### Explore and Remove Duplicates
#
# * drop all duplicate rows in the DataFrame and keep first existing values if any

# %%
# drop duplicates if there are any
cols = df.columns.to_list()
# df = df.drop_duplicates(subset=cols, keep='first')
# df.info()
df.duplicated(subset=cols, keep='first').sum()
# Out:
# 0

# %% [markdown]
# ### Identify And Address Missing Values
#
# As we can see there are missing values in a couple of columns below > **Item_Weight** and **Outlet_Size**
#
# Take note that **Outlet_Size** is a categorical varibale

# %%
# find which variables has missing values
df.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %% [markdown]
# #### Missing Numerical Variable (MCAR)
# Item_Weight is considered as MCAR as there are no found relations between other variables, thus we will be using `Single Value Imputation` and we will be using the `Mean` value as replacement of missing values for this variable.

# %%
# replacing Item_Weight missing values
iw_mean = df['Item_Weight'].mean()
df['Item_Weight'] = df['Item_Weight'].fillna(iw_mean)
df.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                     0
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %% [markdown]
# #### Imputation Using Datawig
#
# Impute missing values in a dataframe

# %%
# initialize a SimpleImputer model
df_train, df_test = datawig.utils.random_split(df)
imputer = datawig.SimpleImputer(
    input_columns = cols,
    output_column='Outlet_Size',
    output_path = 'imputer_model'
)

# Fit an imputer model on the train data
imputer.fit(train_df=df_train, num_epochs=50)

# Impute missing values and return original dataframe with predictions
imputed = imputer.predict(df_test)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3509: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# 2022-04-10 19:17:59,318 [INFO]  NumExpr defaulting to 2 threads.
# 2022-04-10 19:18:01,629 [INFO]
# ========== start: fit model
# 2022-04-10 19:18:01,633 [WARNING]  Already bound, ignoring bind()
# 2022-04-10 19:18:04,793 [INFO]  Epoch[0] Batch [0-138]	Speed: 706.06 samples/sec	cross-entropy=0.583714	Outlet_Size-accuracy=0.787770
# 2022-04-10 19:18:09,460 [INFO]  Epoch[0] Train-cross-entropy=0.419880
# 2022-04-10 19:18:09,465 [INFO]  Epoch[0] Train-Outlet_Size-accuracy=0.880888
# 2022-04-10 19:18:09,472 [INFO]  Epoch[0] Time cost=7.831
# 2022-04-10 19:18:09,490 [INFO]  Saved checkpoint to "imputer_model/model-0000.params"
# 2022-04-10 19:18:10,751 [INFO]  Epoch[0] Validation-cross-entropy=0.189466
# 2022-04-10 19:18:10,761 [INFO]  Epoch[0] Validation-Outlet_Size-accuracy=0.985887
# 2022-04-10 19:18:15,862 [INFO]  Epoch[1] Batch [0-138]	Speed: 435.93 samples/sec	cross-entropy=0.149728	Outlet_Size-accuracy=0.996853
# 2022-04-10 19:18:21,849 [INFO]  Epoch[1] Train-cross-entropy=0.122850
# 2022-04-10 19:18:21,855 [INFO]  Epoch[1] Train-Outlet_Size-accuracy=0.998188
# 2022-04-10 19:18:21,863 [INFO]  Epoch[1] Time cost=11.101
# 2022-04-10 19:18:21,901 [INFO]  Saved checkpoint to "imputer_model/model-0001.params"
# 2022-04-10 19:18:22,754 [INFO]  Epoch[1] Validation-cross-entropy=0.082232
# 2022-04-10 19:18:22,757 [INFO]  Epoch[1] Validation-Outlet_Size-accuracy=0.997984
# 2022-04-10 19:18:26,789 [INFO]  Epoch[2] Batch [0-138]	Speed: 552.33 samples/sec	cross-entropy=0.068895	Outlet_Size-accuracy=0.999550
# 2022-04-10 19:18:29,466 [INFO]  Epoch[2] Train-cross-entropy=0.059685
# 2022-04-10 19:18:29,468 [INFO]  Epoch[2] Train-Outlet_Size-accuracy=0.999774
# 2022-04-10 19:18:29,471 [INFO]  Epoch[2] Time cost=6.712
# 2022-04-10 19:18:29,487 [INFO]  Saved checkpoint to "imputer_model/model-0002.params"
# 2022-04-10 19:18:29,972 [INFO]  Epoch[2] Validation-cross-entropy=0.045816
# 2022-04-10 19:18:29,974 [INFO]  Epoch[2] Validation-Outlet_Size-accuracy=1.000000
# 2022-04-10 19:18:32,707 [INFO]  Epoch[3] Batch [0-138]	Speed: 815.21 samples/sec	cross-entropy=0.039790	Outlet_Size-accuracy=1.000000
# 2022-04-10 19:18:35,402 [INFO]  Epoch[3] Train-cross-entropy=0.035528
# 2022-04-10 19:18:35,404 [INFO]  Epoch[3] Train-Outlet_Size-accuracy=1.000000
# 2022-04-10 19:18:35,411 [INFO]  Epoch[3] Time cost=5.434
# 2022-04-10 19:18:35,422 [INFO]  Saved checkpoint to "imputer_model/model-0003.params"
# 2022-04-10 19:18:35,907 [INFO]  Epoch[3] Validation-cross-entropy=0.029399
# 2022-04-10 19:18:35,909 [INFO]  Epoch[3] Validation-Outlet_Size-accuracy=1.000000
# 2022-04-10 19:18:38,636 [INFO]  Epoch[4] Batch [0-138]	Speed: 817.11 samples/sec	cross-entropy=0.025984	Outlet_Size-accuracy=1.000000
# 2022-04-10 19:18:41,291 [INFO]  Epoch[4] Train-cross-entropy=0.023622
# 2022-04-10 19:18:41,293 [INFO]  Epoch[4] Train-Outlet_Size-accuracy=1.000000
# 2022-04-10 19:18:41,301 [INFO]  Epoch[4] Time cost=5.389
# 2022-04-10 19:18:41,312 [INFO]  Saved checkpoint to "imputer_model/model-0004.params"
# 2022-04-10 19:18:41,804 [INFO]  Epoch[4] Validation-cross-entropy=0.020449
# 2022-04-10 19:18:41,806 [INFO]  Epoch[4] Validation-Outlet_Size-accuracy=1.000000
# 2022-04-10 19:18:44,523 [INFO]  Epoch[5] Batch [0-138]	Speed: 820.54 samples/sec	cross-entropy=0.018245	Outlet_Size-accuracy=1.000000
# 2022-04-10 19:18:47,189 [INFO]  Epoch[5] Train-cross-entropy=0.016799
# 2022-04-10 19:18:47,191 [INFO]  Epoch[5] Train-Outlet_Size-accuracy=1.000000
# 2022-04-10 19:18:47,195 [INFO]  Epoch[5] Time cost=5.386
# 2022-04-10 19:18:47,207 [INFO]  Saved checkpoint to "imputer_model/model-0005.params"
# 2022-04-10 19:18:47,695 [INFO]  Epoch[5] Validation-cross-entropy=0.015025
# 2022-04-10 19:18:47,698 [INFO]  Epoch[5] Validation-Outlet_Size-accuracy=1.000000
# 2022-04-10 19:18:50,384 [INFO]  Epoch[6] Batch [0-138]	Speed: 829.30 samples/sec	cross-entropy=0.013463	Outlet_Size-accuracy=1.000000
# 2022-04-10 19:18:53,051 [INFO]  Epoch[6] Train-cross-entropy=0.012505
# 2022-04-10 19:18:53,055 [INFO]  Epoch[6] Train-Outlet_Size-accuracy=1.000000
# 2022-04-10 19:18:53,060 [INFO]  Epoch[6] Time cost=5.360
# 2022-04-10 19:18:53,070 [INFO]  Saved checkpoint to "imputer_model/model-0006.params"
# 2022-04-10 19:18:53,556 [INFO]  Epoch[6] Validation-cross-entropy=0.011448
# 2022-04-10 19:18:53,558 [INFO]  Epoch[6] Validation-Outlet_Size-accuracy=1.000000
# 2022-04-10 19:18:56,260 [INFO]  Epoch[7] Batch [0-138]	Speed: 824.68 samples/sec	cross-entropy=0.010269	Outlet_Size-accuracy=1.000000
# 2022-04-10 19:18:58,928 [INFO]  Epoch[7] Train-cross-entropy=0.009601
# 2022-04-10 19:18:58,930 [INFO]  Epoch[7] Train-Outlet_Size-accuracy=1.000000
# 2022-04-10 19:18:58,935 [INFO]  Epoch[7] Time cost=5.374
# 2022-04-10 19:18:58,951 [INFO]  Saved checkpoint to "imputer_model/model-0007.params"
# 2022-04-10 19:18:59,435 [INFO]  Epoch[7] Validation-cross-entropy=0.008954
# 2022-04-10 19:18:59,437 [INFO]  Epoch[7] Validation-Outlet_Size-accuracy=1.000000
# 2022-04-10 19:19:02,207 [INFO]  Epoch[8] Batch [0-138]	Speed: 804.78 samples/sec	cross-entropy=0.008038	Outlet_Size-accuracy=1.000000
# 2022-04-10 19:19:04,936 [INFO]  Epoch[8] Train-cross-entropy=0.007555
# 2022-04-10 19:19:04,939 [INFO]  Epoch[8] Train-Outlet_Size-accuracy=1.000000
# 2022-04-10 19:19:04,945 [INFO]  Epoch[8] Time cost=5.504
# 2022-04-10 19:19:04,955 [INFO]  Saved checkpoint to "imputer_model/model-0008.params"
# 2022-04-10 19:19:05,453 [INFO]  Epoch[8] Validation-cross-entropy=0.007157
# 2022-04-10 19:19:05,455 [INFO]  Epoch[8] Validation-Outlet_Size-accuracy=1.000000
# 2022-04-10 19:19:08,148 [INFO]  Epoch[9] Batch [0-138]	Speed: 827.84 samples/sec	cross-entropy=0.006423	Outlet_Size-accuracy=1.000000
# 2022-04-10 19:19:10,787 [INFO]  Epoch[9] Train-cross-entropy=0.006060
# 2022-04-10 19:19:10,789 [INFO]  Epoch[9] Train-Outlet_Size-accuracy=1.000000
# 2022-04-10 19:19:10,796 [INFO]  Epoch[9] Time cost=5.337
# 2022-04-10 19:19:10,807 [INFO]  Saved checkpoint to "imputer_model/model-0009.params"
# 2022-04-10 19:19:11,308 [INFO]  Epoch[9] Validation-cross-entropy=0.005795
# 2022-04-10 19:19:11,313 [INFO]  Epoch[9] Validation-Outlet_Size-accuracy=1.000000
# 2022-04-10 19:19:14,023 [INFO]  Epoch[10] Batch [0-138]	Speed: 822.69 samples/sec	cross-entropy=0.005211	Outlet_Size-accuracy=1.000000
# 2022-04-10 19:19:16,672 [INFO]  Epoch[10] Train-cross-entropy=0.004930
# 2022-04-10 19:19:16,674 [INFO]  Epoch[10] Train-Outlet_Size-accuracy=1.000000
# 2022-04-10 19:19:16,678 [INFO]  Epoch[10] Time cost=5.363
# 2022-04-10 19:19:16,695 [INFO]  Saved checkpoint to "imputer_model/model-0010.params"
# 2022-04-10 19:19:17,184 [INFO]  Epoch[10] Validation-cross-entropy=0.004750
# 2022-04-10 19:19:17,186 [INFO]  Epoch[10] Validation-Outlet_Size-accuracy=1.000000
# 2022-04-10 19:19:19,876 [INFO]  Epoch[11] Batch [0-138]	Speed: 828.24 samples/sec	cross-entropy=0.004275	Outlet_Size-accuracy=1.000000
# 2022-04-10 19:19:22,537 [INFO]  Epoch[11] Train-cross-entropy=0.004054
# 2022-04-10 19:19:22,540 [INFO]  Epoch[11] Train-Outlet_Size-accuracy=1.000000
# 2022-04-10 19:19:22,543 [INFO]  Epoch[11] Time cost=5.354
# 2022-04-10 19:19:22,557 [INFO]  Saved checkpoint to "imputer_model/model-0011.params"
# 2022-04-10 19:19:23,040 [INFO]  Epoch[11] Validation-cross-entropy=0.003941
# 2022-04-10 19:19:23,046 [INFO]  Epoch[11] Validation-Outlet_Size-accuracy=1.000000
# 2022-04-10 19:19:25,747 [INFO]  Epoch[12] Batch [0-138]	Speed: 824.78 samples/sec	cross-entropy=0.003541	Outlet_Size-accuracy=1.000000
# 2022-04-10 19:19:28,402 [INFO]  Epoch[12] Train-cross-entropy=0.003364
# 2022-04-10 19:19:28,405 [INFO]  Epoch[12] Train-Outlet_Size-accuracy=1.000000
# 2022-04-10 19:19:28,408 [INFO]  Epoch[12] Time cost=5.359
# 2022-04-10 19:19:28,424 [INFO]  Saved checkpoint to "imputer_model/model-0012.params"
# 2022-04-10 19:19:28,908 [INFO]  Epoch[12] Validation-cross-entropy=0.003291
# 2022-04-10 19:19:28,910 [INFO]  Epoch[12] Validation-Outlet_Size-accuracy=1.000000
# 2022-04-10 19:19:31,605 [INFO]  Epoch[13] Batch [0-138]	Speed: 826.85 samples/sec	cross-entropy=0.002954	Outlet_Size-accuracy=1.000000
# 2022-04-10 19:19:34,245 [INFO]  Epoch[13] Train-cross-entropy=0.002811
# 2022-04-10 19:19:34,247 [INFO]  Epoch[13] Train-Outlet_Size-accuracy=1.000000
# 2022-04-10 19:19:34,252 [INFO]  Epoch[13] Time cost=5.340
# 2022-04-10 19:19:34,264 [INFO]  Saved checkpoint to "imputer_model/model-0013.params"
# 2022-04-10 19:19:34,759 [INFO]  Epoch[13] Validation-cross-entropy=0.002764
# 2022-04-10 19:19:34,762 [INFO]  Epoch[13] Validation-Outlet_Size-accuracy=1.000000
# 2022-04-10 19:19:37,465 [INFO]  Epoch[14] Batch [0-138]	Speed: 825.23 samples/sec	cross-entropy=0.002479	Outlet_Size-accuracy=1.000000
# 2022-04-10 19:19:40,120 [INFO]  Epoch[14] Train-cross-entropy=0.002362
# 2022-04-10 19:19:40,122 [INFO]  Epoch[14] Train-Outlet_Size-accuracy=1.000000
# 2022-04-10 19:19:40,125 [INFO]  Epoch[14] Time cost=5.358
# 2022-04-10 19:19:40,137 [INFO]  Saved checkpoint to "imputer_model/model-0014.params"
# 2022-04-10 19:19:40,628 [INFO]  Epoch[14] Validation-cross-entropy=0.002337
# 2022-04-10 19:19:40,631 [INFO]  Epoch[14] Validation-Outlet_Size-accuracy=1.000000
# 2022-04-10 19:19:43,334 [INFO]  Epoch[15] Batch [0-138]	Speed: 824.93 samples/sec	cross-entropy=0.002091	Outlet_Size-accuracy=1.000000
# 2022-04-10 19:19:45,993 [INFO]  Epoch[15] Train-cross-entropy=0.001994
# 2022-04-10 19:19:45,995 [INFO]  Epoch[15] Train-Outlet_Size-accuracy=1.000000
# 2022-04-10 19:19:45,997 [INFO]  Epoch[15] Time cost=5.364
# 2022-04-10 19:19:46,008 [INFO]  Saved checkpoint to "imputer_model/model-0015.params"
# 2022-04-10 19:19:46,506 [INFO]  Epoch[15] Validation-cross-entropy=0.001978
# 2022-04-10 19:19:46,509 [INFO]  Epoch[15] Validation-Outlet_Size-accuracy=1.000000
# 2022-04-10 19:19:49,185 [INFO]  Epoch[16] Batch [0-138]	Speed: 832.39 samples/sec	cross-entropy=0.001770	Outlet_Size-accuracy=1.000000
# 2022-04-10 19:19:51,851 [INFO]  Epoch[16] Train-cross-entropy=0.001690
# 2022-04-10 19:19:51,853 [INFO]  Epoch[16] Train-Outlet_Size-accuracy=1.000000
# 2022-04-10 19:19:51,858 [INFO]  Epoch[16] Time cost=5.348
# 2022-04-10 19:19:51,869 [INFO]  Saved checkpoint to "imputer_model/model-0016.params"
# 2022-04-10 19:19:52,368 [INFO]  Epoch[16] Validation-cross-entropy=0.001685
# 2022-04-10 19:19:52,370 [INFO]  Epoch[16] Validation-Outlet_Size-accuracy=1.000000
# 2022-04-10 19:19:55,289 [INFO]  Epoch[17] Batch [0-138]	Speed: 763.20 samples/sec	cross-entropy=0.001502	Outlet_Size-accuracy=1.000000
# 2022-04-10 19:19:58,176 [INFO]  Epoch[17] Train-cross-entropy=0.001436
# 2022-04-10 19:19:58,179 [INFO]  Epoch[17] Train-Outlet_Size-accuracy=1.000000
# 2022-04-10 19:19:58,188 [INFO]  Epoch[17] Time cost=5.812
# 2022-04-10 19:19:58,200 [INFO]  Saved checkpoint to "imputer_model/model-0017.params"
# 2022-04-10 19:19:58,687 [INFO]  Epoch[17] Validation-cross-entropy=0.001437
# 2022-04-10 19:19:58,689 [INFO]  Epoch[17] Validation-Outlet_Size-accuracy=1.000000
# 2022-04-10 19:20:01,411 [INFO]  Epoch[18] Batch [0-138]	Speed: 818.68 samples/sec	cross-entropy=0.001280	Outlet_Size-accuracy=1.000000
# 2022-04-10 19:20:04,172 [INFO]  Epoch[18] Train-cross-entropy=0.001223
# 2022-04-10 19:20:04,179 [INFO]  Epoch[18] Train-Outlet_Size-accuracy=1.000000
# 2022-04-10 19:20:04,182 [INFO]  Epoch[18] Time cost=5.489
# 2022-04-10 19:20:04,193 [INFO]  Saved checkpoint to "imputer_model/model-0018.params"
# 2022-04-10 19:20:04,697 [INFO]  Epoch[18] Validation-cross-entropy=0.001227
# 2022-04-10 19:20:04,701 [INFO]  Epoch[18] Validation-Outlet_Size-accuracy=1.000000
# 2022-04-10 19:20:07,470 [INFO]  Epoch[19] Batch [0-138]	Speed: 804.58 samples/sec	cross-entropy=0.001092	Outlet_Size-accuracy=1.000000
# 2022-04-10 19:20:10,082 [INFO]  Epoch[19] Train-cross-entropy=0.001045
# 2022-04-10 19:20:10,083 [INFO]  Epoch[19] Train-Outlet_Size-accuracy=1.000000
# 2022-04-10 19:20:10,090 [INFO]  Epoch[19] Time cost=5.387
# 2022-04-10 19:20:10,101 [INFO]  Saved checkpoint to "imputer_model/model-0019.params"
# 2022-04-10 19:20:10,596 [INFO]  Epoch[19] Validation-cross-entropy=0.001053
# 2022-04-10 19:20:10,600 [INFO]  Epoch[19] Validation-Outlet_Size-accuracy=1.000000
# 2022-04-10 19:20:13,323 [INFO]  Epoch[20] Batch [0-138]	Speed: 818.74 samples/sec	cross-entropy=0.000935	Outlet_Size-accuracy=1.000000
# 2022-04-10 19:20:15,962 [INFO]  Epoch[20] Train-cross-entropy=0.000894
# 2022-04-10 19:20:15,964 [INFO]  Epoch[20] Train-Outlet_Size-accuracy=1.000000
# 2022-04-10 19:20:15,969 [INFO]  Epoch[20] Time cost=5.365
# 2022-04-10 19:20:15,984 [INFO]  Saved checkpoint to "imputer_model/model-0020.params"
# 2022-04-10 19:20:16,467 [INFO]  Epoch[20] Validation-cross-entropy=0.000904
# 2022-04-10 19:20:16,469 [INFO]  Epoch[20] Validation-Outlet_Size-accuracy=1.000000
# 2022-04-10 19:20:19,165 [INFO]  Epoch[21] Batch [0-138]	Speed: 827.05 samples/sec	cross-entropy=0.000802	Outlet_Size-accuracy=1.000000
# 2022-04-10 19:20:21,800 [INFO]  Epoch[21] Train-cross-entropy=0.000768
# 2022-04-10 19:20:21,807 [INFO]  Epoch[21] Train-Outlet_Size-accuracy=1.000000
# 2022-04-10 19:20:21,810 [INFO]  Epoch[21] Time cost=5.335
# 2022-04-10 19:20:21,826 [INFO]  Saved checkpoint to "imputer_model/model-0021.params"
# 2022-04-10 19:20:22,303 [INFO]  Epoch[21] Validation-cross-entropy=0.000777
# 2022-04-10 19:20:22,305 [INFO]  Epoch[21] Validation-Outlet_Size-accuracy=1.000000
# 2022-04-10 19:20:24,992 [INFO]  Epoch[22] Batch [0-138]	Speed: 830.26 samples/sec	cross-entropy=0.000689	Outlet_Size-accuracy=1.000000
# 2022-04-10 19:20:27,630 [INFO]  Epoch[22] Train-cross-entropy=0.000660
# 2022-04-10 19:20:27,632 [INFO]  Epoch[22] Train-Outlet_Size-accuracy=1.000000
# 2022-04-10 19:20:27,639 [INFO]  Epoch[22] Time cost=5.327
# 2022-04-10 19:20:27,649 [INFO]  Saved checkpoint to "imputer_model/model-0022.params"
# 2022-04-10 19:20:28,142 [INFO]  Epoch[22] Validation-cross-entropy=0.000669
# 2022-04-10 19:20:28,144 [INFO]  Epoch[22] Validation-Outlet_Size-accuracy=1.000000
# 2022-04-10 19:20:30,830 [INFO]  Epoch[23] Batch [0-138]	Speed: 830.65 samples/sec	cross-entropy=0.000593	Outlet_Size-accuracy=1.000000
# 2022-04-10 19:20:33,455 [INFO]  Epoch[23] Train-cross-entropy=0.000568
# 2022-04-10 19:20:33,457 [INFO]  Epoch[23] Train-Outlet_Size-accuracy=1.000000
# 2022-04-10 19:20:33,460 [INFO]  Epoch[23] Time cost=5.307
# 2022-04-10 19:20:33,471 [INFO]  Saved checkpoint to "imputer_model/model-0023.params"
# 2022-04-10 19:20:33,958 [INFO]  Epoch[23] Validation-cross-entropy=0.000578
# 2022-04-10 19:20:33,964 [INFO]  Epoch[23] Validation-Outlet_Size-accuracy=1.000000
# 2022-04-10 19:20:36,907 [INFO]  Epoch[24] Batch [0-138]	Speed: 756.40 samples/sec	cross-entropy=0.000511	Outlet_Size-accuracy=1.000000
# 2022-04-10 19:20:40,042 [INFO]  Epoch[24] Train-cross-entropy=0.000489
# 2022-04-10 19:20:40,044 [INFO]  Epoch[24] Train-Outlet_Size-accuracy=1.000000
# 2022-04-10 19:20:40,049 [INFO]  Epoch[24] Time cost=6.082
# 2022-04-10 19:20:40,062 [INFO]  Saved checkpoint to "imputer_model/model-0024.params"
# 2022-04-10 19:20:40,545 [INFO]  Epoch[24] Validation-cross-entropy=0.000498
# 2022-04-10 19:20:40,550 [INFO]  Epoch[24] Validation-Outlet_Size-accuracy=1.000000
# 2022-04-10 19:20:43,236 [INFO]  Epoch[25] Batch [0-138]	Speed: 830.04 samples/sec	cross-entropy=0.000441	Outlet_Size-accuracy=1.000000
# 2022-04-10 19:20:45,865 [INFO]  Epoch[25] Train-cross-entropy=0.000422
# 2022-04-10 19:20:45,873 [INFO]  Epoch[25] Train-Outlet_Size-accuracy=1.000000
# 2022-04-10 19:20:45,875 [INFO]  Epoch[25] Time cost=5.322
# 2022-04-10 19:20:45,888 [INFO]  Saved checkpoint to "imputer_model/model-0025.params"
# 2022-04-10 19:20:46,379 [INFO]  Epoch[25] Validation-cross-entropy=0.000432
# 2022-04-10 19:20:46,381 [INFO]  Epoch[25] Validation-Outlet_Size-accuracy=1.000000
# 2022-04-10 19:20:49,069 [INFO]  Epoch[26] Batch [0-138]	Speed: 829.77 samples/sec	cross-entropy=0.000380	Outlet_Size-accuracy=1.000000
# 2022-04-10 19:20:51,743 [INFO]  Epoch[26] Train-cross-entropy=0.000365
# 2022-04-10 19:20:51,744 [INFO]  Epoch[26] Train-Outlet_Size-accuracy=1.000000
# 2022-04-10 19:20:51,749 [INFO]  Epoch[26] Time cost=5.363
# 2022-04-10 19:20:51,761 [INFO]  Saved checkpoint to "imputer_model/model-0026.params"
# 2022-04-10 19:20:52,242 [INFO]  Epoch[26] Validation-cross-entropy=0.000374
# 2022-04-10 19:20:52,243 [INFO]  Epoch[26] Validation-Outlet_Size-accuracy=1.000000
# 2022-04-10 19:20:54,920 [INFO]  Epoch[27] Batch [0-138]	Speed: 833.14 samples/sec	cross-entropy=0.000329	Outlet_Size-accuracy=1.000000
# 2022-04-10 19:20:57,550 [INFO]  Epoch[27] Train-cross-entropy=0.000315
# 2022-04-10 19:20:57,555 [INFO]  Epoch[27] Train-Outlet_Size-accuracy=1.000000
# 2022-04-10 19:20:57,558 [INFO]  Epoch[27] Time cost=5.309
# 2022-04-10 19:20:57,574 [INFO]  Saved checkpoint to "imputer_model/model-0027.params"
# 2022-04-10 19:20:58,057 [INFO]  Epoch[27] Validation-cross-entropy=0.000323
# 2022-04-10 19:20:58,059 [INFO]  Epoch[27] Validation-Outlet_Size-accuracy=1.000000
# 2022-04-10 19:21:00,775 [INFO]  Epoch[28] Batch [0-138]	Speed: 821.19 samples/sec	cross-entropy=0.000284	Outlet_Size-accuracy=1.000000
# 2022-04-10 19:21:03,487 [INFO]  Epoch[28] Train-cross-entropy=0.000273
# 2022-04-10 19:21:03,495 [INFO]  Epoch[28] Train-Outlet_Size-accuracy=1.000000
# 2022-04-10 19:21:03,501 [INFO]  Epoch[28] Time cost=5.438
# 2022-04-10 19:21:03,517 [INFO]  Saved checkpoint to "imputer_model/model-0028.params"
# 2022-04-10 19:21:04,012 [INFO]  Epoch[28] Validation-cross-entropy=0.000280
# 2022-04-10 19:21:04,019 [INFO]  Epoch[28] Validation-Outlet_Size-accuracy=1.000000
# 2022-04-10 19:21:06,739 [INFO]  Epoch[29] Batch [0-138]	Speed: 819.75 samples/sec	cross-entropy=0.000246	Outlet_Size-accuracy=1.000000
# 2022-04-10 19:21:09,387 [INFO]  Epoch[29] Train-cross-entropy=0.000236
# 2022-04-10 19:21:09,388 [INFO]  Epoch[29] Train-Outlet_Size-accuracy=1.000000
# 2022-04-10 19:21:09,394 [INFO]  Epoch[29] Time cost=5.372
# 2022-04-10 19:21:09,407 [INFO]  Saved checkpoint to "imputer_model/model-0029.params"
# 2022-04-10 19:21:09,900 [INFO]  Epoch[29] Validation-cross-entropy=0.000243
# 2022-04-10 19:21:09,902 [INFO]  Epoch[29] Validation-Outlet_Size-accuracy=1.000000
# 2022-04-10 19:21:12,617 [INFO]  Epoch[30] Batch [0-138]	Speed: 820.69 samples/sec	cross-entropy=0.000213	Outlet_Size-accuracy=1.000000
# 2022-04-10 19:21:15,281 [INFO]  Epoch[30] Train-cross-entropy=0.000204
# 2022-04-10 19:21:15,283 [INFO]  Epoch[30] Train-Outlet_Size-accuracy=1.000000
# 2022-04-10 19:21:15,290 [INFO]  Epoch[30] Time cost=5.385
# 2022-04-10 19:21:15,303 [INFO]  Saved checkpoint to "imputer_model/model-0030.params"
# 2022-04-10 19:21:15,786 [INFO]  Epoch[30] Validation-cross-entropy=0.000211
# 2022-04-10 19:21:15,787 [INFO]  Epoch[30] Validation-Outlet_Size-accuracy=1.000000
# 2022-04-10 19:21:18,496 [INFO]  Epoch[31] Batch [0-138]	Speed: 823.92 samples/sec	cross-entropy=0.000185	Outlet_Size-accuracy=1.000000
# 2022-04-10 19:21:21,152 [INFO]  Epoch[31] Train-cross-entropy=0.000177
# 2022-04-10 19:21:21,154 [INFO]  Epoch[31] Train-Outlet_Size-accuracy=1.000000
# 2022-04-10 19:21:21,162 [INFO]  Epoch[31] Time cost=5.368
# 2022-04-10 19:21:21,173 [INFO]  Saved checkpoint to "imputer_model/model-0031.params"
# 2022-04-10 19:21:21,647 [INFO]  Epoch[31] Validation-cross-entropy=0.000183
# 2022-04-10 19:21:21,652 [INFO]  Epoch[31] Validation-Outlet_Size-accuracy=1.000000
# 2022-04-10 19:21:24,354 [INFO]  Epoch[32] Batch [0-138]	Speed: 824.70 samples/sec	cross-entropy=0.000160	Outlet_Size-accuracy=1.000000
# 2022-04-10 19:21:26,998 [INFO]  Epoch[32] Train-cross-entropy=0.000153
# 2022-04-10 19:21:27,000 [INFO]  Epoch[32] Train-Outlet_Size-accuracy=1.000000
# 2022-04-10 19:21:27,007 [INFO]  Epoch[32] Time cost=5.351
# 2022-04-10 19:21:27,020 [INFO]  Saved checkpoint to "imputer_model/model-0032.params"
# 2022-04-10 19:21:27,509 [INFO]  Epoch[32] Validation-cross-entropy=0.000159
# 2022-04-10 19:21:27,511 [INFO]  Epoch[32] Validation-Outlet_Size-accuracy=1.000000
# 2022-04-10 19:21:30,244 [INFO]  Epoch[33] Batch [0-138]	Speed: 815.46 samples/sec	cross-entropy=0.000139	Outlet_Size-accuracy=1.000000
# 2022-04-10 19:21:32,879 [INFO]  Epoch[33] Train-cross-entropy=0.000133
# 2022-04-10 19:21:32,881 [INFO]  Epoch[33] Train-Outlet_Size-accuracy=1.000000
# 2022-04-10 19:21:32,884 [INFO]  Epoch[33] Time cost=5.370
# 2022-04-10 19:21:32,899 [INFO]  Saved checkpoint to "imputer_model/model-0033.params"
# 2022-04-10 19:21:33,388 [INFO]  Epoch[33] Validation-cross-entropy=0.000138
# 2022-04-10 19:21:33,391 [INFO]  Epoch[33] Validation-Outlet_Size-accuracy=1.000000
# 2022-04-10 19:21:36,089 [INFO]  Epoch[34] Batch [0-138]	Speed: 825.86 samples/sec	cross-entropy=0.000121	Outlet_Size-accuracy=1.000000
# 2022-04-10 19:21:38,718 [INFO]  Epoch[34] Train-cross-entropy=0.000116
# 2022-04-10 19:21:38,720 [INFO]  Epoch[34] Train-Outlet_Size-accuracy=1.000000
# 2022-04-10 19:21:38,726 [INFO]  Epoch[34] Time cost=5.333
# 2022-04-10 19:21:38,743 [INFO]  Saved checkpoint to "imputer_model/model-0034.params"
# 2022-04-10 19:21:39,224 [INFO]  Epoch[34] Validation-cross-entropy=0.000120
# 2022-04-10 19:21:39,225 [INFO]  Epoch[34] Validation-Outlet_Size-accuracy=1.000000
# 2022-04-10 19:21:41,916 [INFO]  Epoch[35] Batch [0-138]	Speed: 828.97 samples/sec	cross-entropy=0.000105	Outlet_Size-accuracy=1.000000
# 2022-04-10 19:21:44,572 [INFO]  Epoch[35] Train-cross-entropy=0.000100
# 2022-04-10 19:21:44,574 [INFO]  Epoch[35] Train-Outlet_Size-accuracy=1.000000
# 2022-04-10 19:21:44,577 [INFO]  Epoch[35] Time cost=5.345
# 2022-04-10 19:21:44,589 [INFO]  Saved checkpoint to "imputer_model/model-0035.params"
# 2022-04-10 19:21:45,085 [INFO]  Epoch[35] Validation-cross-entropy=0.000105
# 2022-04-10 19:21:45,088 [INFO]  Epoch[35] Validation-Outlet_Size-accuracy=1.000000
# 2022-04-10 19:21:47,774 [INFO]  Epoch[36] Batch [0-138]	Speed: 829.60 samples/sec	cross-entropy=0.000091	Outlet_Size-accuracy=1.000000
# 2022-04-10 19:21:50,419 [INFO]  Epoch[36] Train-cross-entropy=0.000087
# 2022-04-10 19:21:50,421 [INFO]  Epoch[36] Train-Outlet_Size-accuracy=1.000000
# 2022-04-10 19:21:50,427 [INFO]  Epoch[36] Time cost=5.337
# 2022-04-10 19:21:50,439 [INFO]  Saved checkpoint to "imputer_model/model-0036.params"
# 2022-04-10 19:21:50,939 [INFO]  Epoch[36] Validation-cross-entropy=0.000091
# 2022-04-10 19:21:50,945 [INFO]  Epoch[36] Validation-Outlet_Size-accuracy=1.000000
# 2022-04-10 19:21:53,623 [INFO]  Epoch[37] Batch [0-138]	Speed: 832.20 samples/sec	cross-entropy=0.000079	Outlet_Size-accuracy=1.000000
# 2022-04-10 19:21:56,290 [INFO]  Epoch[37] Train-cross-entropy=0.000076
# 2022-04-10 19:21:56,292 [INFO]  Epoch[37] Train-Outlet_Size-accuracy=1.000000
# 2022-04-10 19:21:56,295 [INFO]  Epoch[37] Time cost=5.348
# 2022-04-10 19:21:56,302 [INFO]  Saved checkpoint to "imputer_model/model-0037.params"
# 2022-04-10 19:21:56,795 [INFO]  Epoch[37] Validation-cross-entropy=0.000080
# 2022-04-10 19:21:56,798 [INFO]  Epoch[37] Validation-Outlet_Size-accuracy=1.000000
# 2022-04-10 19:21:59,505 [INFO]  Epoch[38] Batch [0-138]	Speed: 823.10 samples/sec	cross-entropy=0.000069	Outlet_Size-accuracy=1.000000
# 2022-04-10 19:22:02,196 [INFO]  Epoch[38] Train-cross-entropy=0.000066
# 2022-04-10 19:22:02,198 [INFO]  Epoch[38] Train-Outlet_Size-accuracy=1.000000
# 2022-04-10 19:22:02,205 [INFO]  Epoch[38] Time cost=5.404
# 2022-04-10 19:22:02,216 [INFO]  Saved checkpoint to "imputer_model/model-0038.params"
# 2022-04-10 19:22:02,704 [INFO]  Epoch[38] Validation-cross-entropy=0.000070
# 2022-04-10 19:22:02,706 [INFO]  Epoch[38] Validation-Outlet_Size-accuracy=1.000000
# 2022-04-10 19:22:05,418 [INFO]  Epoch[39] Batch [0-138]	Speed: 821.83 samples/sec	cross-entropy=0.000060	Outlet_Size-accuracy=1.000000
# 2022-04-10 19:22:08,093 [INFO]  Epoch[39] Train-cross-entropy=0.000057
# 2022-04-10 19:22:08,095 [INFO]  Epoch[39] Train-Outlet_Size-accuracy=1.000000
# 2022-04-10 19:22:08,101 [INFO]  Epoch[39] Time cost=5.391
# 2022-04-10 19:22:08,114 [INFO]  Saved checkpoint to "imputer_model/model-0039.params"
# 2022-04-10 19:22:08,600 [INFO]  Epoch[39] Validation-cross-entropy=0.000061
# 2022-04-10 19:22:08,602 [INFO]  Epoch[39] Validation-Outlet_Size-accuracy=1.000000
# 2022-04-10 19:22:11,306 [INFO]  Epoch[40] Batch [0-138]	Speed: 824.07 samples/sec	cross-entropy=0.000052	Outlet_Size-accuracy=1.000000
# 2022-04-10 19:22:13,969 [INFO]  Epoch[40] Train-cross-entropy=0.000050
# 2022-04-10 19:22:13,971 [INFO]  Epoch[40] Train-Outlet_Size-accuracy=1.000000
# 2022-04-10 19:22:13,976 [INFO]  Epoch[40] Time cost=5.372
# 2022-04-10 19:22:13,991 [INFO]  Saved checkpoint to "imputer_model/model-0040.params"
# 2022-04-10 19:22:14,483 [INFO]  Epoch[40] Validation-cross-entropy=0.000053
# 2022-04-10 19:22:14,489 [INFO]  Epoch[40] Validation-Outlet_Size-accuracy=1.000000
# 2022-04-10 19:22:17,215 [INFO]  Epoch[41] Batch [0-138]	Speed: 817.81 samples/sec	cross-entropy=0.000045	Outlet_Size-accuracy=1.000000
# 2022-04-10 19:22:19,857 [INFO]  Epoch[41] Train-cross-entropy=0.000044
# 2022-04-10 19:22:19,859 [INFO]  Epoch[41] Train-Outlet_Size-accuracy=1.000000
# 2022-04-10 19:22:19,864 [INFO]  Epoch[41] Time cost=5.373
# 2022-04-10 19:22:19,875 [INFO]  Saved checkpoint to "imputer_model/model-0041.params"
# 2022-04-10 19:22:20,373 [INFO]  Epoch[41] Validation-cross-entropy=0.000046
# 2022-04-10 19:22:20,378 [INFO]  Epoch[41] Validation-Outlet_Size-accuracy=1.000000
# 2022-04-10 19:22:23,080 [INFO]  Epoch[42] Batch [0-138]	Speed: 824.54 samples/sec	cross-entropy=0.000040	Outlet_Size-accuracy=1.000000
# 2022-04-10 19:22:25,740 [INFO]  Epoch[42] Train-cross-entropy=0.000038
# 2022-04-10 19:22:25,745 [INFO]  Epoch[42] Train-Outlet_Size-accuracy=1.000000
# 2022-04-10 19:22:25,750 [INFO]  Epoch[42] Time cost=5.367
# 2022-04-10 19:22:25,760 [INFO]  Saved checkpoint to "imputer_model/model-0042.params"
# 2022-04-10 19:22:26,246 [INFO]  Epoch[42] Validation-cross-entropy=0.000040
# 2022-04-10 19:22:26,248 [INFO]  Epoch[42] Validation-Outlet_Size-accuracy=1.000000
# 2022-04-10 19:22:28,970 [INFO]  Epoch[43] Batch [0-138]	Speed: 818.75 samples/sec	cross-entropy=0.000035	Outlet_Size-accuracy=1.000000
# 2022-04-10 19:22:31,632 [INFO]  Epoch[43] Train-cross-entropy=0.000033
# 2022-04-10 19:22:31,634 [INFO]  Epoch[43] Train-Outlet_Size-accuracy=1.000000
# 2022-04-10 19:22:31,639 [INFO]  Epoch[43] Time cost=5.388
# 2022-04-10 19:22:31,651 [INFO]  Saved checkpoint to "imputer_model/model-0043.params"
# 2022-04-10 19:22:32,142 [INFO]  Epoch[43] Validation-cross-entropy=0.000035
# 2022-04-10 19:22:32,147 [INFO]  Epoch[43] Validation-Outlet_Size-accuracy=1.000000
# 2022-04-10 19:22:34,813 [INFO]  Epoch[44] Batch [0-138]	Speed: 835.82 samples/sec	cross-entropy=0.000030	Outlet_Size-accuracy=1.000000
# 2022-04-10 19:22:37,447 [INFO]  Epoch[44] Train-cross-entropy=0.000029
# 2022-04-10 19:22:37,454 [INFO]  Epoch[44] Train-Outlet_Size-accuracy=1.000000
# 2022-04-10 19:22:37,456 [INFO]  Epoch[44] Time cost=5.304
# 2022-04-10 19:22:37,468 [INFO]  Saved checkpoint to "imputer_model/model-0044.params"
# 2022-04-10 19:22:37,954 [INFO]  Epoch[44] Validation-cross-entropy=0.000031
# 2022-04-10 19:22:37,960 [INFO]  Epoch[44] Validation-Outlet_Size-accuracy=1.000000
# 2022-04-10 19:22:40,659 [INFO]  Epoch[45] Batch [0-138]	Speed: 825.16 samples/sec	cross-entropy=0.000026	Outlet_Size-accuracy=1.000000
# 2022-04-10 19:22:43,354 [INFO]  Epoch[45] Train-cross-entropy=0.000025
# 2022-04-10 19:22:43,362 [INFO]  Epoch[45] Train-Outlet_Size-accuracy=1.000000
# 2022-04-10 19:22:43,364 [INFO]  Epoch[45] Time cost=5.403
# 2022-04-10 19:22:43,377 [INFO]  Saved checkpoint to "imputer_model/model-0045.params"
# 2022-04-10 19:22:43,863 [INFO]  Epoch[45] Validation-cross-entropy=0.000027
# 2022-04-10 19:22:43,866 [INFO]  Epoch[45] Validation-Outlet_Size-accuracy=1.000000
# 2022-04-10 19:22:46,566 [INFO]  Epoch[46] Batch [0-138]	Speed: 825.78 samples/sec	cross-entropy=0.000023	Outlet_Size-accuracy=1.000000
# 2022-04-10 19:22:49,248 [INFO]  Epoch[46] Train-cross-entropy=0.000022
# 2022-04-10 19:22:49,250 [INFO]  Epoch[46] Train-Outlet_Size-accuracy=1.000000
# 2022-04-10 19:22:49,255 [INFO]  Epoch[46] Time cost=5.384
# 2022-04-10 19:22:49,268 [INFO]  Saved checkpoint to "imputer_model/model-0046.params"
# 2022-04-10 19:22:49,753 [INFO]  Epoch[46] Validation-cross-entropy=0.000024
# 2022-04-10 19:22:49,755 [INFO]  Epoch[46] Validation-Outlet_Size-accuracy=1.000000
# 2022-04-10 19:22:52,468 [INFO]  Epoch[47] Batch [0-138]	Speed: 822.04 samples/sec	cross-entropy=0.000020	Outlet_Size-accuracy=1.000000
# 2022-04-10 19:22:55,148 [INFO]  Epoch[47] Train-cross-entropy=0.000019
# 2022-04-10 19:22:55,151 [INFO]  Epoch[47] Train-Outlet_Size-accuracy=1.000000
# 2022-04-10 19:22:55,155 [INFO]  Epoch[47] Time cost=5.394
# 2022-04-10 19:22:55,167 [INFO]  Saved checkpoint to "imputer_model/model-0047.params"
# 2022-04-10 19:22:55,653 [INFO]  Epoch[47] Validation-cross-entropy=0.000021
# 2022-04-10 19:22:55,658 [INFO]  Epoch[47] Validation-Outlet_Size-accuracy=1.000000
# 2022-04-10 19:22:58,383 [INFO]  Epoch[48] Batch [0-138]	Speed: 818.43 samples/sec	cross-entropy=0.000018	Outlet_Size-accuracy=1.000000
# 2022-04-10 19:23:01,072 [INFO]  Epoch[48] Train-cross-entropy=0.000017
# 2022-04-10 19:23:01,078 [INFO]  Epoch[48] Train-Outlet_Size-accuracy=1.000000
# 2022-04-10 19:23:01,084 [INFO]  Epoch[48] Time cost=5.420
# 2022-04-10 19:23:01,095 [INFO]  Saved checkpoint to "imputer_model/model-0048.params"
# 2022-04-10 19:23:01,596 [INFO]  Epoch[48] Validation-cross-entropy=0.000018
# 2022-04-10 19:23:01,601 [INFO]  Epoch[48] Validation-Outlet_Size-accuracy=1.000000
# 2022-04-10 19:23:04,347 [INFO]  Epoch[49] Batch [0-138]	Speed: 811.14 samples/sec	cross-entropy=0.000015	Outlet_Size-accuracy=1.000000
# 2022-04-10 19:23:07,053 [INFO]  Epoch[49] Train-cross-entropy=0.000015
# 2022-04-10 19:23:07,058 [INFO]  Epoch[49] Train-Outlet_Size-accuracy=1.000000
# 2022-04-10 19:23:07,063 [INFO]  Epoch[49] Time cost=5.459
# 2022-04-10 19:23:07,077 [INFO]  Saved checkpoint to "imputer_model/model-0049.params"
# 2022-04-10 19:23:07,577 [INFO]  Epoch[49] Validation-cross-entropy=0.000016
# 2022-04-10 19:23:07,582 [INFO]  Epoch[49] Validation-Outlet_Size-accuracy=1.000000
# 2022-04-10 19:23:07,586 [INFO]
# ========== done (305.958101272583 s) fit model

# %%
# analyze imputed dataframe 
os_missing = imputed['Outlet_Size'].isna()
imputed.loc[os_missing, :]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 4167           FDT40        5.985          Low Fat         0.095990
# 619            FDO19       17.700          Regular         0.016630
# 7759           NCK30       14.850          Low Fat         0.102066
# 4376           FDZ02        6.905          Regular         0.063851
# 3044           FDR26       20.700          Low Fat         0.071700
# ...              ...          ...              ...              ...
# 1406           DRG15        6.130          Low Fat         0.076892
# 6899           FDX52       11.500          Regular         0.042088
# 6400           FDT43       16.350          Low Fat         0.034393
# 1520           FDF12        8.235          Low Fat         0.082595
# 7293           FDL38       13.800          Regular         0.024660
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 4167           Frozen Foods  127.3678            OUT045
# 619   Fruits and Vegetables   48.1034            OUT045
# 7759              Household  254.2698            OUT010
# 4376                  Dairy   97.2726            OUT010
# 3044                  Dairy  177.6028            OUT010
# ...                     ...       ...               ...
# 1406                  Dairy   61.5536            OUT045
# 6899           Frozen Foods  192.6820            OUT045
# 6400  Fruits and Vegetables   50.8324            OUT010
# 1520           Baking Goods  149.1076            OUT045
# 7293                 Canned   87.4172            OUT010
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 4167                       2002         NaN               Tier 2
# 619                        2002         NaN               Tier 2
# 7759                       1998         NaN               Tier 3
# 4376                       1998         NaN               Tier 3
# 3044                       1998         NaN               Tier 3
# ...                         ...         ...                  ...
# 1406                       2002         NaN               Tier 2
# 6899                       2002         NaN               Tier 2
# 6400                       1998         NaN               Tier 3
# 1520                       2002         NaN               Tier 2
# 7293                       1998         NaN               Tier 3
#
#             Outlet_Type  Item_Outlet_Sales Outlet_Size_imputed  \
# 4167  Supermarket Type1           508.6712               Small
# 619   Supermarket Type1           534.6374               Small
# 7759      Grocery Store          1775.6886               Small
# 4376      Grocery Store           195.7452               Small
# 3044      Grocery Store           531.3084               Small
# ...                 ...                ...                 ...
# 1406  Supermarket Type1           796.2968               Small
# 6899  Supermarket Type1          3861.6400               Small
# 6400      Grocery Store           155.7972               Small
# 1520  Supermarket Type1          1182.4608               Small
# 7293      Grocery Store           178.4344               Small
#
#       Outlet_Size_imputed_proba
# 4167                   0.963192
# 619                    0.938289
# 7759                   0.998052
# 4376                   0.999012
# 3044                   0.999617
# ...                         ...
# 1406                   0.978833
# 6899                   0.972943
# 6400                   0.998384
# 1520                   0.967243
# 7293                   0.999062
#
# [486 rows x 14 columns]

# %%
# assign imputed dataframe as clean dataframe and drop other uneccessary columns and rename Outlet_Size_imputed as Outlet_Size
cleaned_df = imputed.drop(columns = ['Outlet_Size','Outlet_Size_imputed_proba'])
cleaned_df = cleaned_df.rename(columns={'Outlet_Size_imputed':'Outlet_Size'})
cleaned_df.isna().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# Outlet_Size                  0
# dtype: int64

# %% [markdown]
# ### Fix Incosistent categories of Data
#
# * Check for inconsistencies
# * Fix inconsistencies

# %%
# check inconsistencies in the categorical values
cat_df = cleaned_df.select_dtypes(include=[np.object])
for col in list(cat_df):
  print(col + ":")
  print(" > Count of unique values:" + str(len(cat_df[col].unique())))
  print(cat_df[col].unique())
# Out:
# Item_Identifier:
#  > Count of unique values:1069
# ['FDT40' 'FDT09' 'FDQ25' ... 'FDT43' 'FDF12' 'FDQ10']
# Item_Fat_Content:
#  > Count of unique values:5
# ['Low Fat' 'Regular' 'LF' 'low fat' 'reg']
# Item_Type:
#  > Count of unique values:16
# ['Frozen Foods' 'Snack Foods' 'Canned' 'Fruits and Vegetables' 'Meat'
#  'Soft Drinks' 'Household' 'Hard Drinks' 'Others' 'Dairy' 'Baking Goods'
#  'Breads' 'Health and Hygiene' 'Starchy Foods' 'Breakfast' 'Seafood']
# Outlet_Identifier:
#  > Count of unique values:10
# ['OUT045' 'OUT049' 'OUT035' 'OUT046' 'OUT018' 'OUT019' 'OUT010' 'OUT013'
#  'OUT017' 'OUT027']
# Outlet_Location_Type:
#  > Count of unique values:3
# ['Tier 2' 'Tier 1' 'Tier 3']
# Outlet_Type:
#  > Count of unique values:4
# ['Supermarket Type1' 'Supermarket Type2' 'Grocery Store'
#  'Supermarket Type3']
# Outlet_Size:
#  > Count of unique values:3
# ['Small' 'Medium' 'High']

# %%
# fix inconsistencies found in Item_Fat_Content column
cleaned_df['Item_Fat_Content'] = cleaned_df['Item_Fat_Content'].replace(['low fat', 'LF', 'reg'],['Low Fat','Low Fat','Regular'])
cleaned_df['Item_Fat_Content'].unique()
# Out:
# array(['Low Fat', 'Regular'], dtype=object)

# %% [markdown]
# ### Obtain the summarry statistics
#
# * Summary statistics of each numerical column

# %%
# summary statistics of each numerical columns
df.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  8523.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.226124         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       9.310000         0.026989    93.826500                1987.000000
# 50%      12.857645         0.053931   143.012800                1999.000000
# 75%      16.000000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800
